# %% [markdown]
# # 1. Libraries setup

# %%
import sys

# %%
! pip install keras
! pip install matplotlib
! pip install sklearn
! pip install pandas
! pip install pydot
! pip install tensorflow
! pip install numpy
! pip install opencv-python
! pip install scipy
! pip install astropy
# Out:
# Requirement already satisfied: keras in /Users/francoterranova/lib/python3.9/site-packages (2.11.0)
# Requirement already satisfied: matplotlib in /Users/francoterranova/lib/python3.9/site-packages (3.6.2)
# Requirement already satisfied: numpy>=1.19 in /Users/francoterranova/lib/python3.9/site-packages (from matplotlib) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /Users/francoterranova/lib/python3.9/site-packages (from matplotlib) (21.3)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/francoterranova/lib/python3.9/site-packages (from matplotlib) (1.0.6)
# Requirement already satisfied: pillow>=6.2.0 in /Users/francoterranova/lib/python3.9/site-packages (from matplotlib) (9.3.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/francoterranova/lib/python3.9/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in /Users/francoterranova/lib/python3.9/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/francoterranova/lib/python3.9/site-packages (from matplotlib) (4.38.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/francoterranova/lib/python3.9/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/francoterranova/lib/python3.9/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: six>=1.5 in /Users/francoterranova/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: sklearn in /Users/francoterranova/lib/python3.9/site-packages (0.0.post1)
# Requirement already satisfied: pandas in /Users/francoterranova/lib/python3.9/site-packages (1.5.2)
# Requirement already satisfied: numpy>=1.20.3 in /Users/francoterranova/lib/python3.9/site-packages (from pandas) (1.23.5)
# Requirement already satisfied: pytz>=2020.1 in /Users/francoterranova/lib/python3.9/site-packages (from pandas) (2022.6)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/francoterranova/lib/python3.9/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in /Users/francoterranova/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: pydot in /Users/francoterranova/lib/python3.9/site-packages (1.4.2)
# Requirement already satisfied: pyparsing>=2.1.4 in /Users/francoterranova/lib/python3.9/site-packages (from pydot) (3.0.9)
# Requirement already satisfied: tensorflow in /Users/francoterranova/lib/python3.9/site-packages (2.11.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Users/francoterranova/lib/python3.9/site-packages (from tensorflow) (4.4.0)
# Requirement already satisfied: h5py>=2.9.0 in /Users/francoterranova/lib/python3.9/site-packages (from tensorflow) (3.7.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Users/francoterranova/lib/python3.9/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: tensorflow-estimator<2.12,>=2.11.0 in /Users/francoterranova/lib/python3.9/site-packages (from tensorflow) (2.11.0)
# Requirement already satisfied: flatbuffers>=2.0 in /Users/francoterranova/lib/python3.9/site-packages (from tensorflow) (22.11.23)
# Requirement already satisfied: libclang>=13.0.0 in /Users/francoterranova/lib/python3.9/site-packages (from tensorflow) (14.0.6)
# Requirement already satisfied: numpy>=1.20 in /Users/francoterranova/lib/python3.9/site-packages (from tensorflow) (1.23.5)
# Requirement already satisfied: tensorboard<2.12,>=2.11 in /Users/francoterranova/lib/python3.9/site-packages (from tensorflow) (2.11.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /Users/francoterranova/lib/python3.9/site-packages (from tensorflow) (0.28.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /Users/francoterranova/lib/python3.9/site-packages (from tensorflow) (3.19.6)
# Requirement already satisfied: six>=1.12.0 in /Users/francoterranova/lib/python3.9/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: setuptools in /Users/francoterranova/lib/python3.9/site-packages (from tensorflow) (60.2.0)
# Requirement already satisfied: wrapt>=1.11.0 in /Users/francoterranova/lib/python3.9/site-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/francoterranova/lib/python3.9/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: packaging in /Users/francoterranova/lib/python3.9/site-packages (from tensorflow) (21.3)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/francoterranova/lib/python3.9/site-packages (from tensorflow) (1.51.1)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/francoterranova/lib/python3.9/site-packages (from tensorflow) (1.3.0)
# Requirement already satisfied: keras<2.12,>=2.11.0 in /Users/francoterranova/lib/python3.9/site-packages (from tensorflow) (2.11.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /Users/francoterranova/lib/python3.9/site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/francoterranova/lib/python3.9/site-packages (from tensorflow) (2.1.1)
# Requirement already satisfied: google-pasta>=0.1.1 in /Users/francoterranova/lib/python3.9/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/francoterranova/lib/python3.9/site-packages (from astunparse>=1.6.0->tensorflow) (0.37.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/francoterranova/lib/python3.9/site-packages (from tensorboard<2.12,>=2.11->tensorflow) (2.28.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /Users/francoterranova/lib/python3.9/site-packages (from tensorboard<2.12,>=2.11->tensorflow) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /Users/francoterranova/lib/python3.9/site-packages (from tensorboard<2.12,>=2.11->tensorflow) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/francoterranova/lib/python3.9/site-packages (from tensorboard<2.12,>=2.11->tensorflow) (2.2.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /Users/francoterranova/lib/python3.9/site-packages (from tensorboard<2.12,>=2.11->tensorflow) (2.15.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /Users/francoterranova/lib/python3.9/site-packages (from tensorboard<2.12,>=2.11->tensorflow) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in /Users/francoterranova/lib/python3.9/site-packages (from tensorboard<2.12,>=2.11->tensorflow) (3.4.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/francoterranova/lib/python3.9/site-packages (from packaging->tensorflow) (3.0.9)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/francoterranova/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/francoterranova/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/francoterranova/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow) (5.2.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/francoterranova/lib/python3.9/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /Users/francoterranova/lib/python3.9/site-packages (from markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow) (5.1.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/francoterranova/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/francoterranova/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow) (2022.9.24)
# Requirement already satisfied: idna<4,>=2.5 in /Users/francoterranova/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/francoterranova/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow) (1.26.13)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/francoterranova/lib/python3.9/site-packages (from werkzeug>=1.0.1->tensorboard<2.12,>=2.11->tensorflow) (2.1.1)
# Requirement already satisfied: zipp>=0.5 in /Users/francoterranova/lib/python3.9/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow) (3.11.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /Users/francoterranova/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/francoterranova/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow) (3.2.2)
# Requirement already satisfied: numpy in /Users/francoterranova/lib/python3.9/site-packages (1.23.5)
# Requirement already satisfied: opencv-python in /Users/francoterranova/lib/python3.9/site-packages (4.6.0.66)
# Requirement already satisfied: numpy>=1.14.5 in /Users/francoterranova/lib/python3.9/site-packages (from opencv-python) (1.23.5)
# Requirement already satisfied: scipy in /Users/francoterranova/lib/python3.9/site-packages (1.9.3)
# Requirement already satisfied: numpy<1.26.0,>=1.18.5 in /Users/francoterranova/lib/python3.9/site-packages (from scipy) (1.23.5)
# Requirement already satisfied: astropy in /Users/francoterranova/lib/python3.9/site-packages (5.1.1)
# Requirement already satisfied: pyerfa>=2.0 in /Users/francoterranova/lib/python3.9/site-packages (from astropy) (2.0.0.1)
# Requirement already satisfied: numpy>=1.18 in /Users/francoterranova/lib/python3.9/site-packages (from astropy) (1.23.5)
# Requirement already satisfied: PyYAML>=3.13 in /Users/francoterranova/lib/python3.9/site-packages (from astropy) (6.0)
# Requirement already satisfied: packaging>=19.0 in /Users/francoterranova/lib/python3.9/site-packages (from astropy) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/francoterranova/lib/python3.9/site-packages (from packaging>=19.0->astropy) (3.0.9)

# %%
# OS-dependent
if sys.platform.startswith("linux"):  # Linux-like
    ! apt install graphviz
elif sys.platform == "darwin": # MacOS
    ! brew install graphviz
# Out:
# Running `brew update --auto-update`...
# ==> Auto-updated Homebrew!
# Updated 2 taps (homebrew/core and homebrew/cask).
# ==> New Formulae
# akku                       ghc@9.2                    naga-cli
# aribb24                    go-task                    oauth2c
# brpc                       gobackup                   php@8.1
# buf                        grammarly-languageserver   sapling
# busted                     grantlee                   seven-kingdoms
# clitest                    hermit                     snakefmt
# clusterawsadm              ibazel                     souffle
# cocogitto                  jscpd                      spectral-cli
# code-cli                   kubefirst                  sql-language-server
# countdown                  libisofs                   standard
# dotnet@6                   licensed                   stylelint
# erigon                     luacheck                   totp-cli
# gf                         metals                     zf
# ==> New Casks
# agi                        elephas                    overt
# cursr                      farcaster                  vincelwt-chatgpt
#
# You have 6 outdated formulae installed.
# You can upgrade them with brew upgrade
# or list them with brew outdated.
#
# graphviz 7.0.2 is already installed but outdated (so it will be upgraded).
# ==> Downloading https://ghcr.io/v2/homebrew/core/glib/manifests/2.74.3
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/glib/blobs/sha256:8f12510a26c04
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/jasper/manifests/4.0.0
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/jasper/blobs/sha256:24dd3e8e090
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/netpbm/manifests/10.86.35_1
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/netpbm/blobs/sha256:a8dd82da44c
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/pixman/manifests/0.42.2
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/pixman/blobs/sha256:701df7463b3
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/graphviz/manifests/7.0.4
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/graphviz/blobs/sha256:700517284
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Upgrading graphviz
#   7.0.2 -> 7.0.4
#
# ==> Installing dependencies for graphviz: glib, jasper, netpbm and pixman
# ==> Installing graphviz dependency: glib
# ==> Pouring glib--2.74.3.ventura.bottle.tar.gz
# 🍺  /usr/local/Cellar/glib/2.74.3: 448 files, 20.7MB
# ==> Installing graphviz dependency: jasper
# ==> Pouring jasper--4.0.0.ventura.bottle.tar.gz
# 🍺  /usr/local/Cellar/jasper/4.0.0: 44 files, 1.5MB
# ==> Installing graphviz dependency: netpbm
# ==> Pouring netpbm--10.86.35_1.ventura.bottle.tar.gz
# 🍺  /usr/local/Cellar/netpbm/10.86.35_1: 408 files, 12.8MB
# ==> Installing graphviz dependency: pixman
# ==> Pouring pixman--0.42.2.ventura.bottle.tar.gz
# 🍺  /usr/local/Cellar/pixman/0.42.2: 11 files, 1.3MB
# ==> Installing graphviz
# ==> Pouring graphviz--7.0.4.ventura.bottle.tar.gz
# 🍺  /usr/local/Cellar/graphviz/7.0.4: 285 files, 6.5MB
# ==> Running `brew cleanup graphviz`...
# Disable this behaviour by setting HOMEBREW_NO_INSTALL_CLEANUP.
# Hide these hints with HOMEBREW_NO_ENV_HINTS (see `man brew`).
# Removing: /usr/local/Cellar/graphviz/7.0.2... (285 files, 6.5MB)
# Removing: /Users/francoterranova/Library/Caches/Homebrew/graphviz--7.0.2... (2.6MB)

# %% [markdown]
# # 2. Folders setup

# %%
import os

# %%
paths = {
    'MODEL_DIR': os.path.join('model'),
    'LOG_DIR' : os.path.join('model', 'log_dir'),
    'IMAGES_PATH': os.path.join('workspace','images','all'),
    'ANNOTATION_PATH': os.path.join('workspace','annotations'),
    'RAW_DATA_PATH' : os.path.join('workspace', 'raw_data'),
    'RESULTS_PATH': os.path.join('workspace','results'),
    'TRANSFER_LEARNING_RESULTS': os.path.join('workspace','transfer_learning_results')
 }

# %%
# create paths
for path in paths.values():
    if not os.path.exists(path):
        if os.name == 'posix': # Unix-like
            # !mkdir -p {path}
        if os.name == 'nt': # Windows
            # !mkdir {path}

# %% [markdown]
# # 3. Convert h5 file to jpg images using astroNN (2nd version)

# %%
! pip install astroNN
# Out:
# Requirement already satisfied: astroNN in /Users/francoterranova/lib/python3.9/site-packages (1.0.1)
# Requirement already satisfied: matplotlib in /Users/francoterranova/lib/python3.9/site-packages (from astroNN) (3.6.2)
# Requirement already satisfied: pandas in /Users/francoterranova/lib/python3.9/site-packages (from astroNN) (1.5.2)
# Requirement already satisfied: h5py in /Users/francoterranova/lib/python3.9/site-packages (from astroNN) (3.7.0)
# Requirement already satisfied: astropy in /Users/francoterranova/lib/python3.9/site-packages (from astroNN) (5.1.1)
# Requirement already satisfied: tqdm in /Users/francoterranova/lib/python3.9/site-packages (from astroNN) (4.64.1)
# Requirement already satisfied: packaging in /Users/francoterranova/lib/python3.9/site-packages (from astroNN) (21.3)
# Requirement already satisfied: scikit-learn in /Users/francoterranova/lib/python3.9/site-packages (from astroNN) (1.2.0)
# Requirement already satisfied: astroquery in /Users/francoterranova/lib/python3.9/site-packages (from astroNN) (0.4.6)
# Requirement already satisfied: numpy in /Users/francoterranova/lib/python3.9/site-packages (from astroNN) (1.23.5)
# Requirement already satisfied: seaborn in /Users/francoterranova/lib/python3.9/site-packages (from astroNN) (0.12.1)
# Requirement already satisfied: PyYAML>=3.13 in /Users/francoterranova/lib/python3.9/site-packages (from astropy->astroNN) (6.0)
# Requirement already satisfied: pyerfa>=2.0 in /Users/francoterranova/lib/python3.9/site-packages (from astropy->astroNN) (2.0.0.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/francoterranova/lib/python3.9/site-packages (from packaging->astroNN) (3.0.9)
# Requirement already satisfied: beautifulsoup4>=4.3.2 in /Users/francoterranova/lib/python3.9/site-packages (from astroquery->astroNN) (4.11.1)
# Requirement already satisfied: keyring>=4.0 in /Users/francoterranova/lib/python3.9/site-packages (from astroquery->astroNN) (23.11.0)
# Requirement already satisfied: requests>=2.4.3 in /Users/francoterranova/lib/python3.9/site-packages (from astroquery->astroNN) (2.28.1)
# Requirement already satisfied: html5lib>=0.999 in /Users/francoterranova/lib/python3.9/site-packages (from astroquery->astroNN) (1.1)
# Requirement already satisfied: pyvo>=1.1 in /Users/francoterranova/lib/python3.9/site-packages (from astroquery->astroNN) (1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/francoterranova/lib/python3.9/site-packages (from matplotlib->astroNN) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in /Users/francoterranova/lib/python3.9/site-packages (from matplotlib->astroNN) (9.3.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/francoterranova/lib/python3.9/site-packages (from matplotlib->astroNN) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /Users/francoterranova/lib/python3.9/site-packages (from matplotlib->astroNN) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/francoterranova/lib/python3.9/site-packages (from matplotlib->astroNN) (1.0.6)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/francoterranova/lib/python3.9/site-packages (from matplotlib->astroNN) (4.38.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/francoterranova/lib/python3.9/site-packages (from pandas->astroNN) (2022.6)
# Requirement already satisfied: joblib>=1.1.1 in /Users/francoterranova/lib/python3.9/site-packages (from scikit-learn->astroNN) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/francoterranova/lib/python3.9/site-packages (from scikit-learn->astroNN) (3.1.0)
# Requirement already satisfied: scipy>=1.3.2 in /Users/francoterranova/lib/python3.9/site-packages (from scikit-learn->astroNN) (1.9.3)
# Requirement already satisfied: soupsieve>1.2 in /Users/francoterranova/lib/python3.9/site-packages (from beautifulsoup4>=4.3.2->astroquery->astroNN) (2.3.2.post1)
# Requirement already satisfied: six>=1.9 in /Users/francoterranova/lib/python3.9/site-packages (from html5lib>=0.999->astroquery->astroNN) (1.16.0)
# Requirement already satisfied: webencodings in /Users/francoterranova/lib/python3.9/site-packages (from html5lib>=0.999->astroquery->astroNN) (0.5.1)
# Requirement already satisfied: jaraco.classes in /Users/francoterranova/lib/python3.9/site-packages (from keyring>=4.0->astroquery->astroNN) (3.2.3)
# Requirement already satisfied: importlib-metadata>=4.11.4 in /Users/francoterranova/lib/python3.9/site-packages (from keyring>=4.0->astroquery->astroNN) (5.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/francoterranova/lib/python3.9/site-packages (from requests>=2.4.3->astroquery->astroNN) (2022.9.24)
# Requirement already satisfied: idna<4,>=2.5 in /Users/francoterranova/lib/python3.9/site-packages (from requests>=2.4.3->astroquery->astroNN) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/francoterranova/lib/python3.9/site-packages (from requests>=2.4.3->astroquery->astroNN) (1.26.13)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/francoterranova/lib/python3.9/site-packages (from requests>=2.4.3->astroquery->astroNN) (2.1.1)
# Requirement already satisfied: zipp>=0.5 in /Users/francoterranova/lib/python3.9/site-packages (from importlib-metadata>=4.11.4->keyring>=4.0->astroquery->astroNN) (3.11.0)
# Requirement already satisfied: more-itertools in /Users/francoterranova/lib/python3.9/site-packages (from jaraco.classes->keyring>=4.0->astroquery->astroNN) (9.0.0)

# %%
from astroNN.datasets import load_galaxy10
import numpy as np
import os
from PIL import Image
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

images, labels = load_galaxy10()

print(images.size)
print(labels.size)
df = pd.DataFrame()

print("Removing previous images...")
for file in os.listdir(os.path.join('workspace', 'images', 'all')):
    if file != ".DS_Store":
        os.remove(os.path.join('workspace', 'images', 'all', file))

print("Saving images in the correct folder...")
for i in range(0,labels.size):
    image = images[i]
    label = labels[i]
    new_row = {'Path':str(i)+".jpg", 'Class':labels[i]}
    df = df.append(new_row, ignore_index=True)
    im = Image.fromarray(image)
    im.save(os.path.join('workspace', 'images', 'all',str(i)+".jpg"))
    if i % 100 == 0:
        print(i)
df.to_csv(os.path.join('workspace','annotations','annotations.csv'), index=False)
# Out:
# /Users/francoterranova/.astroNN/datasets/Galaxy10.h5 was found!
# 311155155
# 21785
# Removing previous images...
# Saving images in the correct folder...
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000
# 6100
# 6200
# 6300
# 6400
# 6500
# 6600
# 6700
# 6800
# 6900
# 7000
# 7100
# 7200
# 7300
# 7400
# 7500
# 7600
# 7700
# 7800
# 7900
# 8000
# 8100
# 8200
# 8300
# 8400
# 8500
# 8600
# 8700
# 8800
# 8900
# 9000
# 9100
# 9200
# 9300
# 9400
# 9500
# 9600
# 9700
# 9800
# 9900
# 10000
# 10100
# 10200
# 10300
# 10400
# 10500
# 10600
# 10700
# 10800
# 10900
# 11000
# 11100
# 11200
# 11300
# 11400
# 11500
# 11600
# 11700
# 11800
# 11900
# 12000
# 12100
# 12200
# 12300
# 12400
# 12500
# 12600
# 12700
# 12800
# 12900
# 13000
# 13100
# 13200
# 13300
# 13400
# 13500
# 13600
# 13700
# 13800
# 13900
# 14000
# 14100
# 14200
# 14300
# 14400
# 14500
# 14600
# 14700
# 14800
# 14900
# 15000
# 15100
# 15200
# 15300
# 15400
# 15500
# 15600
# 15700
# 15800
# 15900
# 16000
# 16100
# 16200
# 16300
# 16400
# 16500
# 16600
# 16700
# 16800
# 16900
# 17000
# 17100
# 17200
# 17300
# 17400
# 17500
# 17600
# 17700
# 17800
# 17900
# 18000
# 18100
# 18200
# 18300
# 18400
# 18500
# 18600
# 18700
# 18800
# 18900
# 19000
# 19100
# 19200
# 19300
# 19400
# 19500
# 19600
# 19700
# 19800
# 19900
# 20000
# 20100
# 20200
# 20300
# 20400
# 20500
# 20600
# 20700
# 20800
# 20900
# 21000
# 21100
# 21200
# 21300
# 21400
# 21500
# 21600
# 21700

# %%
# other version to test, use directly h5 file
# #import os
#import h5py
#import numpy as np
#from keras import utils
#from matplotlib import pyplot as plt
#import time

#for filename in os.listdir(os.path.join("workspace","raw_data")):
#    if filename.endswith(".h5"):
#        with h5py.File(os.path.join("workspace","raw_data",filename), 'r') as F:
#            images = np.array(F['images'])
#            labels = np.array(F['ans'])
#            print(images)
#            print(labels)
            # convert the labels to categorical 10 classes
#            labels = utils.to_categorical(labels, 10)

            # To convert to desirable type
#            labels = labels.astype(np.float32)
#            images = images.astype(np.float32)
#            print(images)
#            print(labels)
#            for image in images:
#                plt.imshow(image, interpolation='nearest')
#                plt.show()
#                time.sleep(5000)
